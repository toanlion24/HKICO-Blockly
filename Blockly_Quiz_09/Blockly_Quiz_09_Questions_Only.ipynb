# %% [markdown]
# # BLOCKLY PROGRAMMING - QUIZ 09
# ## 30 Multiple Choice Questions (50% Theory | 50% Practice)
# ### Difficulty: Advanced | Theory & Challenging Code Analysis

# %% [markdown]
# ---
# ## THEORY QUESTIONS (50%)
# ---

# %% [markdown]
# ### Question 1: For Each vs Indexed For
#
# What is the main advantage of `for each [item] in list [myList]` over `for [i] from [1] to [length of myList]`?
#
# A) `for each` is always faster
# B) `for each` automatically provides the index
# C) `for each` iterates over values directly without needing index
# D) `for each` can modify the list during iteration
# E) `for each` runs exactly once

# %% [markdown]
# ### Question 2: Double NOT Logic
#
# If `x = false`, what is the result of `NOT (NOT x)`?
#
# A) true
# B) false
# C) Error
# D) undefined
# E) null

# %% [markdown]
# ### Question 3: First vs Last List Item
#
# In Blockly, if `myList = [100, 200, 300, 400]`, what does `item [1] of [myList]` return?
#
# A) 400
# B) 100
# C) 4
# D) Error
# E) [100, 200, 300, 400]

# %% [markdown]
# ### Question 4: Empty List Length
#
# In Blockly, what is `length of [create empty list]`?
#
# A) Error
# B) 1
# C) 0
# D) undefined
# E) null

# %% [markdown]
# ### Question 5: Join with Empty String
#
# In Blockly, what is the result of `join("A", join("", "B"))`?
#
# A) "AB"
# B) "A B"
# C) "AB "
# D) Error
# E) "A"

# %% [markdown]
# ### Question 6: Exclusive Range Check
#
# Which expression correctly checks if `n` is strictly between 5 and 15 (exclusive)?
#
# A) `n >= 5 AND n <= 15`
# B) `n > 5 AND n < 15`
# C) `n > 5 OR n < 15`
# D) `5 < n < 15`
# E) `n = 6 OR n = 7 OR ... OR n = 14`

# %% [markdown]
# ### Question 7: Repeat N Times
#
# What does `repeat [0] times` do in Blockly?
#
# A) Runs forever
# B) Runs exactly once
# C) Does not run the inner block at all
# D) Causes an error
# E) Runs 10 times (default)

# %% [markdown]
# ### Question 8: Insert Item at Position
#
# In Blockly, if you use `insert [X] at [1] of [list]`, where does X appear?
#
# A) At the end of the list
# B) At the beginning (index 1 in 1-based)
# C) Replaces the item at position 1
# D) At position 2
# E) Random position

# %% [markdown]
# ### Question 9: Arithmetic Precedence
#
# In Blockly, what is the result of `[[15] / [3]] + [[4] * [2]]`?
#
# A) 14
# B) 13
# C) 12
# D) 11
# E) 10

# %% [markdown]
# ### Question 10: Modulo Result Range
#
# In Blockly, for positive integers, what is the range of `[a] mod [b]` when b > 0?
#
# A) 0 to b
# B) 0 to b-1
# C) 1 to b
# D) 0 to a
# E) -b to b

# %% [markdown]
# ### Question 11: Last Letter Index
#
# In Blockly, if `s = "HELLO"`, what does `letter [length of [s]] in [s]` return?
#
# A) "H"
# B) "O"
# C) 5
# D) "HELLO"
# E) Error

# %% [markdown]
# ### Question 12: Create List With
#
# What does `create list with [5], [10], [15]` produce in Blockly?
#
# A) A list [5, 10, 15]
# B) The number 30
# C) A single item 5
# D) Error - invalid syntax
# E) A string "5,10,15"

# %% [markdown]
# ### Question 13: Length of Empty String
#
# In Blockly, what is `length of [""]`?
#
# A) Error
# B) 1
# C) 0
# D) undefined
# E) null

# %% [markdown]
# ### Question 14: Single Loop Iterations
#
# How many times does the body run in `for [k] from [2] to [8] by [2]`?
#
# A) 3
# B) 4
# C) 5
# D) 6
# E) 8

# %% [markdown]
# ### Question 15: Round vs Floor
#
# In Blockly, what is `round [2.6]` and how does it differ from `floor of [2.6]`?
#
# A) round=2, floor=2 (same)
# B) round=3, floor=2 (round rounds to nearest; floor rounds down)
# C) round=2, floor=3
# D) Both round to nearest: 2
# E) round=2.6, floor=2

# %% [markdown]
# ---
# ## APPLICATION QUESTIONS (50%) - Advanced Difficulty
# ---

# %% [markdown]
# ### Question 16: Nested Loop Multiplication Count
#
# Analyze this code:
#
# ```
# set [count] to [0]
# for [i] from [1] to [4] by [1]
#     for [j] from [1] to [i] by [1]
#         if <[[i] + [j]] mod [2]> = [1] then
#             change [count] by [1]
# set [result] to [count]
# ```
#
# What is the final value of `result`?
#
# A) 4
# B) 5
# C) 6
# D) 7
# E) 8

# %% [markdown]
# ### Question 17: Repeat Until Counter
#
# Examine this code:
#
# ```
# set [n] to [64]
# set [steps] to [0]
# repeat until <[n] ≤ [1]>
#     set [n] to [floor of [[n] / [2]]]
#     change [steps] by [1]
# set [result] to [steps]
# ```
#
# What is the final value of `result`?
#
# A) 5
# B) 6
# C) 7
# D) 8
# E) 64

# %% [markdown]
# ### Question 18: List Odd Numbers Sum
#
# Given this code:
#
# ```
# set [data] to [create list with: 3, 8, 11, 6, 15, 4, 9]
# set [sum] to [0]
# for each [x] in list [data]
#     if <[x] mod [2]> = [1] then
#         if <[x] > [5]> then
#             change [sum] by [x]
# ```
#
# What is the final value of `sum`?
#
# A) 23
# B) 35
# C) 38
# D) 41
# E) 56

# %% [markdown]
# ### Question 19: Vowel Counter
#
# Analyze this code:
#
# ```
# set [word] to ["PROGRAMMING"]
# set [vowels] to [0]
# for [i] from [1] to [length of [word]] by [1]
#     set [c] to [letter [i] in [word]]
#     if <[c] = ["O"] or [c] = ["I"] or [c] = ["A"]> then
#         change [vowels] by [1]
# set [result] to [vowels]
# ```
#
# What is the final value of `result`?
#
# A) 2
# B) 3
# C) 4
# D) 5
# E) 6

# %% [markdown]
# ### Question 20: Arithmetic Sequence
#
# Examine this code:
#
# ```
# set [a] to [2]
# set [d] to [5]
# repeat [5] times
#     set [a] to [[a] + [d]]
# set [result] to [a]
# ```
#
# What is the final value of `result`?
#
# A) 22
# B) 27
# C) 32
# D) 37
# E) 42

# %% [markdown]
# ### Question 21: Divisibility by 2 and 3
#
# Given this code:
#
# ```
# set [count] to [0]
# for [n] from [1] to [24] by [1]
#     if <[n] mod [2]> = [0] and <[n] mod [3]> = [0] then
#         change [count] by [1]
# set [result] to [count]
# ```
#
# What is the final value of `result`?
#
# A) 2
# B) 4
# C) 6
# D) 8
# E) 12

# %% [markdown]
# ### Question 22: List Shift Sum (First Items)
#
# Analyze this code:
#
# ```
# set [lst] to [create list with: 7, 14, 21, 28, 35]
# set [total] to [0]
# repeat [3] times
#     set [first] to [item [1] of [lst]]
#     change [total] by [first]
#     delete item [1] of [lst]
# set [result] to [total]
# ```
#
# What is the final value of `result`?
#
# A) 21
# B) 42
# C) 63
# D) 84
# E) 105

# %% [markdown]
# ### Question 23: Odd Digits Sum
#
# Examine this code:
#
# ```
# set [num] to [2946]
# set [result] to [0]
# repeat while <[num] > [0]>
#     set [d] to [[num] mod [10]]
#     if <[d] mod [2]> = [1] then
#         change [result] by [d]
#     set [num] to [floor of [[num] / [10]]]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 9
# C) 11
# D) 15
# E) 21

# %% [markdown]
# ### Question 24: Min Value and Index
#
# Given this code (assume list has positive numbers):
#
# ```
# set [arr] to [create list with: 12, 5, 18, 3, 9, 7]
# set [minVal] to [item [1] of [arr]]
# set [minIdx] to [1]
# for [i] from [2] to [length of [arr]] by [1]
#     if <item [i] of [arr]> < [minVal] then
#         set [minVal] to [item [i] of [arr]]
#         set [minIdx] to [i]
# set [result] to [[minVal] + [minIdx]]
# ```
#
# What is the final value of `result`?
#
# A) 3
# B) 4
# C) 5
# D) 6
# E) 7

# %% [markdown]
# ### Question 25: Sum of Squares
#
# Analyze this code:
#
# ```
# set [n] to [5]
# set [sum] to [0]
# for [i] from [1] to [n] by [1]
#     set [sum] to [[sum] + [[i] * [i]]]
# set [result] to [sum]
# ```
#
# What is the final value of `result`?
#
# A) 15
# B) 25
# C) 35
# D) 55
# E) 65

# %% [markdown]
# ### Question 26: First and Last Letter Match
#
# Examine this code:
#
# ```
# set [word] to ["RADAR"]
# set [len] to [length of [word]]
# set [match] to [0]
# if <letter [1] in [word]> = <letter [len] in [word]> then
#     set [match] to [1]
# if <letter [2] in [word]> = <letter [[len] - [1]] in [word]> then
#     change [match] by [1]
# set [result] to [match]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 1
# C) 2
# D) 3
# E) 5

# %% [markdown]
# ### Question 27: Alternating Sign Sum
#
# Given this code:
#
# ```
# set [total] to [0]
# set [sign] to [1]
# repeat [4] times
#     set [total] to [[total] + [[sign] * [3]]]
#     set [sign] to [[sign] * [-1]]
# set [result] to [total]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 3
# C) 6
# D) 12
# E) -12

# %% [markdown]
# ### Question 28: Product Modulo 7
#
# Analyze this code:
#
# ```
# set [vals] to [create list with: 3, 4, 5]
# set [prod] to [1]
# for each [v] in list [vals]
#     set [prod] to [[prod] * [v]]
# set [result] to [[prod] mod [7]]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 1
# C) 4
# D) 5
# E) 6

# %% [markdown]
# ### Question 29: Grade Tiers Counter
#
# Examine this code:
#
# ```
# set [grades] to [create list with: 95, 72, 88, 65, 91, 78]
# set [A_count] to [0]
# set [B_count] to [0]
# for each [g] in list [grades]
#     if <[g] ≥ [90]> then
#         change [A_count] by [1]
#     else
#         if <[g] ≥ [75]> then
#             change [B_count] by [1]
# set [result] to [[A_count] * [10] + [B_count]]
# ```
#
# What is the final value of `result`?
#
# A) 22
# B) 23
# C) 32
# D) 33
# E) 42

# %% [markdown]
# ### Question 30: Diagonal Sum Pattern
#
# Given this code:
#
# ```
# set [sum] to [0]
# for [r] from [1] to [4] by [1]
#     for [c] from [1] to [4] by [1]
#         if <[r]> = [c] then
#             set [sum] to [[sum] + [[r] + [c]]]
# set [result] to [sum]
# ```
#
# What is the final value of `result`?
#
# A) 20
# B) 24
# C) 28
# D) 32
# E) 40
