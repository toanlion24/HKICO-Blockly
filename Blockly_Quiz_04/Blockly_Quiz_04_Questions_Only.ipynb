# %% [markdown]
# # BLOCKLY PROGRAMMING - QUIZ 04
# ## 20 Advanced Multiple Choice Questions
# ### Difficulty: Hard | Combined Knowledge Application

# %% [markdown]
# ---
# ## THEORY QUESTIONS (30%)
# ---

# %% [markdown]
# ### Question 1: Loop Behavior
#
# What is the difference between `repeat while` and `repeat until` loops in Blockly?
#
# A) There is no difference; they work the same way
# B) `repeat while` continues when condition is TRUE; `repeat until` continues when condition is FALSE
# C) `repeat while` runs exactly once; `repeat until` can run multiple times
# D) `repeat while` is faster than `repeat until`
# E) `repeat until` can only be used with numbers

# %% [markdown]
# ---
# ### Question 2: Boolean Logic
#
# If `x = true` and `y = false`, what is the result of `(x AND y) OR (NOT y)`?
#
# A) true
# B) false
# C) Error
# D) undefined
# E) null

# %% [markdown]
# ---
# ### Question 3: List Indexing
#
# In Blockly, if `myList = [10, 20, 30, 40, 50]`, what does `item (length of myList) of myList` return?
#
# A) 10
# B) 50
# C) 5
# D) Error: index out of bounds
# E) 40

# %% [markdown]
# ---
# ### Question 4: Variable Scope
#
# In Blockly, if you create a variable inside a loop, where can you access it?
#
# A) Only inside that loop
# B) Anywhere in the entire program (global scope)
# C) Only in the function where it was created
# D) Only after the loop ends
# E) Nowhere, loop variables are automatically deleted

# %% [markdown]
# ---
# ### Question 5: String Operations
#
# In Blockly, what is the result of `join("AB", join("CD", "EF"))`?
#
# A) "ABCDEF"
# B) "AB CD EF"
# C) "CDEFAB"
# D) "AB" "CDEF"
# E) Error

# %% [markdown]
# ---
# ### Question 6: Comparison Operators
#
# Which expression correctly checks if a number `n` is between 10 and 20 (inclusive)?
#
# A) `n > 10 AND n < 20`
# B) `n >= 10 AND n <= 20`
# C) `n >= 10 OR n <= 20`
# D) `10 < n < 20`
# E) `n = 10 OR n = 20`

# %% [markdown]
# ---
# ## APPLICATION QUESTIONS (70%)
# ---

# %% [markdown]
# ---
# ### Question 7: Nested Loop with Condition
#
# Analyze the following code:
#
# ```
# set [total] to [0]
#
# for [i] from [1] to [3] by [1]
#     for [j] from [1] to [4] by [1]
#         if <[i] + [j]> is even then
#             change [total] by [1]
# ```
#
# What is the final value of `total`?
#
# A) 4
# B) 6
# C) 8
# D) 10
# E) 12

# %% [markdown]
# ---
# ### Question 8: Complex Counter
#
# Examine this code:
#
# ```
# set [x] to [100]
# set [count] to [0]
#
# repeat while <[x] > [1]>
#     if <[x] mod [2]> = [0] then
#         set [x] to [[x] / [2]]
#     else
#         set [x] to [[x] - [1]]
#     change [count] by [1]
# ```
#
# What is the final value of `count`?
#
# A) 7
# B) 8
# C) 9
# D) 10
# E) 100

# %% [markdown]
# ---
# ### Question 9: List Filtering and Sum
#
# Given this code:
#
# ```
# set [numbers] to [create list with: 12, 7, 18, 3, 25, 10, 8]
# set [result] to [0]
#
# for each [n] in list [numbers]
#     if <[n] > [5]> and <[n] < [20]> then
#         if <[n] mod [2]> = [0] then
#             change [result] by [n]
# ```
#
# What is the final value of `result`?
#
# A) 30
# B) 40
# C) 48
# D) 55
# E) 70

# %% [markdown]
# ---
# ### Question 10: String Pattern
#
# Analyze this code:
#
# ```
# set [word] to ["BANANA"]
# set [count] to [0]
# set [prev] to [""]
#
# for [i] from [1] to [length of [word]] by [1]
#     set [curr] to [letter [i] in [word]]
#     if <[curr]> = [prev] then
#         change [count] by [1]
#     set [prev] to [curr]
# ```
#
# What is the final value of `count`?
#
# A) 0
# B) 1
# C) 2
# D) 3
# E) 6

# %% [markdown]
# ---
# ### Question 11: Two-Variable Pattern
#
# Examine this code:
#
# ```
# set [a] to [3]
# set [b] to [5]
#
# repeat [4] times
#     set [temp] to [a]
#     set [a] to [b]
#     set [b] to [[temp] + [b]]
#
# set [result] to [b]
# ```
#
# What is the final value of `result`?
#
# A) 21
# B) 34
# C) 55
# D) 89
# E) 144

# %% [markdown]
# ---
# ### Question 12: Divisibility Counter
#
# Given this code:
#
# ```
# set [count] to [0]
#
# for [n] from [1] to [30] by [1]
#     if <[n] mod [3]> = [0] or <[n] mod [5]> = [0] then
#         change [count] by [1]
# ```
#
# What is the final value of `count`?
#
# A) 10
# B) 12
# C) 14
# D) 16
# E) 18

# %% [markdown]
# ---
# ### Question 13: List Manipulation Chain
#
# Analyze this code:
#
# ```
# set [list] to [create list with: 5, 10, 15, 20, 25]
# set [sum] to [0]
#
# repeat [3] times
#     set [last] to [item [length of [list]] of [list]]
#     change [sum] by [last]
#     delete item [length of [list]] of [list]
# ```
#
# What is the final value of `sum`?
#
# A) 30
# B) 45
# C) 60
# D) 75
# E) 50

# %% [markdown]
# ---
# ### Question 14: Digit Extraction
#
# Examine this code:
#
# ```
# set [num] to [3847]
# set [result] to [0]
#
# repeat while <[num] > [0]>
#     set [digit] to [[num] mod [10]]
#     if <[digit] mod [2]> = [0] then
#         change [result] by [digit]
#     set [num] to [floor of [[num] / [10]]]
# ```
#
# What is the final value of `result`?
#
# A) 4
# B) 8
# C) 12
# D) 15
# E) 22

# %% [markdown]
# ---
# ### Question 15: Cumulative Product
#
# Given this code:
#
# ```
# set [nums] to [create list with: 2, 3, 4]
# set [product] to [1]
#
# for each [n] in list [nums]
#     set [product] to [[product] * [n]]
#
# set [result] to [[product] mod [5]]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 1
# C) 2
# D) 3
# E) 4

# %% [markdown]
# ---
# ### Question 16: Conditional Accumulator
#
# Analyze this code:
#
# ```
# set [x] to [1]
# set [total] to [0]
#
# repeat [5] times
#     if <[x] mod [2]> = [1] then
#         change [total] by [x]
#         set [x] to [[x] * [2]]
#     else
#         change [total] by [[x] * [-1]]
#         set [x] to [[x] + [1]]
# ```
#
# What is the final value of `total`?
#
# A) 3
# B) 5
# C) 7
# D) 9
# E) 11

# %% [markdown]
# ---
# ### Question 17: Palindrome Check Pattern
#
# Examine this code:
#
# ```
# set [word] to ["LEVEL"]
# set [len] to [length of [word]]
# set [match] to [0]
#
# for [i] from [1] to [floor of [[len] / [2]]] by [1]
#     if <letter [i] in [word]> = <letter [[len] - [i] + [1]] in [word]> then
#         change [match] by [1]
# ```
#
# What is the final value of `match`?
#
# A) 0
# B) 1
# C) 2
# D) 3
# E) 5

# %% [markdown]
# ---
# ### Question 18: Index Tracking
#
# Given this code:
#
# ```
# set [data] to [create list with: 4, 7, 2, 9, 5, 3]
# set [maxVal] to [0]
# set [maxIdx] to [0]
#
# for [i] from [1] to [length of [data]] by [1]
#     if <item [i] of [data]> > [maxVal] then
#         set [maxVal] to [item [i] of [data]]
#         set [maxIdx] to [i]
#
# set [result] to [[maxVal] * [maxIdx]]
# ```
#
# What is the final value of `result`?
#
# A) 9
# B) 18
# C) 27
# D) 36
# E) 45

# %% [markdown]
# ---
# ### Question 19: Triangular Number
#
# Analyze this code:
#
# ```
# set [n] to [7]
# set [sum] to [0]
#
# for [i] from [1] to [n] by [1]
#     for [j] from [1] to [i] by [1]
#         change [sum] by [1]
# ```
#
# What is the final value of `sum`?
#
# A) 7
# B) 14
# C) 21
# D) 28
# E) 49

# %% [markdown]
# ---
# ### Question 20: Complex Multi-Condition
#
# Examine this comprehensive code:
#
# ```
# set [scores] to [create list with: 85, 92, 78, 95, 88, 70, 100]
# set [bonus] to [0]
# set [count] to [0]
#
# for each [s] in list [scores]
#     if <[s] ≥ [90]> then
#         change [bonus] by [10]
#         change [count] by [1]
#     else if <[s] ≥ [80]> then
#         change [bonus] by [5]
#
# set [result] to [[bonus] + [[count] * [count]]]
# ```
#
# What is the final value of `result`?
#
# A) 35
# B) 40
# C) 49
# D) 50
# E) 55
