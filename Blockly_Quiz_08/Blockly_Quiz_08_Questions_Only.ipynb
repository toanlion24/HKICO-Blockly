# %% [markdown]
# # BLOCKLY PROGRAMMING - QUIZ 08
# ## 30 Multiple Choice Questions (50% Theory | 50% Practice)
# ### Difficulty: Advanced | Theory & Challenging Code Analysis

# %% [markdown]
# ---
# ## THEORY QUESTIONS (50%)
# ---

# %% [markdown]
# ### Question 1: Repeat While vs Repeat Until
#
# What is the difference between `repeat while` and `repeat until` loops in Blockly?
#
# A) There is no difference; they work identically
# B) `repeat while` continues when condition is TRUE; `repeat until` continues when condition is FALSE
# C) `repeat while` runs exactly once; `repeat until` runs until manually stopped
# D) `repeat until` is faster for large iterations
# E) `repeat while` can only use numeric conditions

# %% [markdown]
# ### Question 2: Boolean Logic
#
# If `x = true`, `y = false`, what is the result of `(x AND y) OR (NOT y)`?
#
# A) true
# B) false
# C) Error
# D) undefined
# E) null

# %% [markdown]
# ### Question 3: List Indexing
#
# In Blockly, if `myList = [10, 20, 30, 40, 50]`, what does `item (length of myList) of myList` return?
#
# A) 10
# B) 50
# C) 5
# D) Error: index out of bounds
# E) 40

# %% [markdown]
# ### Question 4: Variable Scope
#
# In Blockly, if you create a variable inside a loop, where can you access it?
#
# A) Only inside that loop
# B) Anywhere in the entire program (global scope)
# C) Only in the function where it was created
# D) Only after the loop ends
# E) Nowhere, loop variables are automatically deleted

# %% [markdown]
# ### Question 5: Nested String Join
#
# In Blockly, what is the result of `join("AB", join("CD", "EF"))`?
#
# A) "ABCDEF"
# B) "AB CD EF"
# C) "CDEFAB"
# D) "AB" "CDEF"
# E) Error

# %% [markdown]
# ### Question 6: Inclusive Range Check
#
# Which expression correctly checks if a number `n` is between 10 and 20 (inclusive)?
#
# A) `n > 10 AND n < 20`
# B) `n >= 10 AND n <= 20`
# C) `n >= 10 OR n <= 20`
# D) `10 < n < 20`
# E) `n = 10 OR n = 20`

# %% [markdown]
# ### Question 7: For Loop Step
#
# What does `for [i] from [1] to [10] by [3]` iterate?
#
# A) i = 1, 2, 3, ..., 10
# B) i = 1, 4, 7, 10
# C) i = 1, 3, 6, 9
# D) i = 3, 6, 9
# E) i = 1 only

# %% [markdown]
# ### Question 8: List Mutation During Iteration
#
# What can happen when deleting items from a list while iterating with `for each [item] in list [myList]`?
#
# A) No issues; Blockly handles it automatically
# B) Some items may be skipped because indices shift after deletion
# C) The program always crashes
# D) All items get deleted automatically
# E) The list becomes read-only during iteration

# %% [markdown]
# ### Question 9: Order of Operations
#
# In Blockly, what is the result of `[[10] - [3]] * [[2] + [1]]`?
#
# A) 5
# B) 21
# C) 7
# D) 3
# E) 25

# %% [markdown]
# ### Question 10: Modulo with Negative
#
# In Blockly, what is the result of `[17] mod [5]`?
#
# A) 3.4
# B) 3
# C) 2
# D) 5
# E) 0

# %% [markdown]
# ### Question 11: Letter Index in Blockly
#
# In Blockly, if `s = "DOG"`, what does `letter [1] in [s]` return?
#
# A) "D"
# B) "O"
# C) "G"
# D) 1
# E) "DOG"

# %% [markdown]
# ### Question 12: Change vs Set
#
# What is the key difference between `set [x] to [5]` and `change [x] by [5]`?
#
# A) Both do exactly the same thing
# B) `set` replaces the value; `change` adds to the current value
# C) `change` only works with lists
# D) `set` only works once per variable
# E) `change` requires x to already exist; `set` does not

# %% [markdown]
# ### Question 13: Length of Join
#
# In Blockly, what is `length of [join ["Hi"] ["!"] ]`?
#
# A) 2
# B) 3
# C) 4
# D) "Hi!"
# E) Error

# %% [markdown]
# ### Question 14: Nested Loop Iterations
#
# How many times does the inner block run in:
# ```
# for [i] from [1] to [3] by [1]
#     for [j] from [1] to [4] by [1]
#         (inner block)
# ```
#
# A) 4
# B) 7
# C) 12
# D) 3
# E) 24

# %% [markdown]
# ### Question 15: Floor vs Round
#
# In Blockly, what is the difference between `floor of [3.7]` and `round [3.7]`?
#
# A) Both return 4
# B) Both return 3
# C) `floor` returns 3, `round` returns 4
# D) `floor` returns 4, `round` returns 3
# E) `floor` rounds up, `round` rounds down

# %% [markdown]
# ---
# ## APPLICATION QUESTIONS (50%) - Advanced Difficulty
# ---

# %% [markdown]
# ### Question 16: Nested Loop with Condition
#
# Analyze this code:
#
# ```
# set [total] to [0]
# for [i] from [1] to [3] by [1]
#     for [j] from [1] to [4] by [1]
#         if <[[i] + [j]] mod [2]> = [0] then
#             change [total] by [1]
# set [result] to [total]
# ```
#
# What is the final value of `result`?
#
# A) 4
# B) 6
# C) 8
# D) 10
# E) 12

# %% [markdown]
# ### Question 17: Complex Counter (Repeat While)
#
# Examine this code:
#
# ```
# set [x] to [100]
# set [count] to [0]
# repeat while <[x] > [1]>
#     if <[x] mod [2]> = [0] then
#         set [x] to [[x] / [2]]
#     else
#         set [x] to [[x] - [1]]
#     change [count] by [1]
# set [result] to [count]
# ```
#
# What is the final value of `result`?
#
# A) 7
# B) 8
# C) 9
# D) 10
# E) 100

# %% [markdown]
# ### Question 18: List Filtering and Sum
#
# Given this code:
#
# ```
# set [numbers] to [create list with: 12, 7, 18, 3, 25, 10, 8]
# set [result] to [0]
# for each [n] in list [numbers]
#     if <[n] > [5]> and <[n] < [20]> then
#         if <[n] mod [2]> = [0] then
#             change [result] by [n]
# ```
#
# What is the final value of `result`?
#
# A) 30
# B) 40
# C) 48
# D) 55
# E) 70

# %% [markdown]
# ### Question 19: String Consecutive Letters
#
# Analyze this code:
#
# ```
# set [word] to ["BANANA"]
# set [count] to [0]
# set [prev] to [""]
# for [i] from [1] to [length of [word]] by [1]
#     set [curr] to [letter [i] in [word]]
#     if <[curr]> = [prev] then
#         change [count] by [1]
#     set [prev] to [curr]
# set [result] to [count]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 1
# C) 2
# D) 3
# E) 6

# %% [markdown]
# ### Question 20: Fibonacci-Like Sequence
#
# Examine this code:
#
# ```
# set [a] to [3]
# set [b] to [5]
# repeat [4] times
#     set [temp] to [a]
#     set [a] to [b]
#     set [b] to [[temp] + [b]]
# set [result] to [b]
# ```
#
# What is the final value of `result`?
#
# A) 21
# B) 34
# C) 55
# D) 89
# E) 144

# %% [markdown]
# ### Question 21: Divisibility Counter
#
# Given this code:
#
# ```
# set [count] to [0]
# for [n] from [1] to [30] by [1]
#     if <[n] mod [3]> = [0] or <[n] mod [5]> = [0] then
#         change [count] by [1]
# set [result] to [count]
# ```
#
# What is the final value of `result`?
#
# A) 10
# B) 12
# C) 14
# D) 16
# E) 18

# %% [markdown]
# ### Question 22: List Pop and Sum
#
# Analyze this code:
#
# ```
# set [list] to [create list with: 5, 10, 15, 20, 25]
# set [sum] to [0]
# repeat [3] times
#     set [last] to [item [length of [list]] of [list]]
#     change [sum] by [last]
#     delete item [length of [list]] of [list]
# set [result] to [sum]
# ```
#
# What is the final value of `result`?
#
# A) 30
# B) 45
# C) 60
# D) 75
# E) 50

# %% [markdown]
# ### Question 23: Digit Extraction (Even Digits Sum)
#
# Examine this code:
#
# ```
# set [num] to [3847]
# set [result] to [0]
# repeat while <[num] > [0]>
#     set [digit] to [[num] mod [10]]
#     if <[digit] mod [2]> = [0] then
#         change [result] by [digit]
#     set [num] to [floor of [[num] / [10]]]
# ```
#
# What is the final value of `result`?
#
# A) 4
# B) 8
# C) 12
# D) 15
# E) 22

# %% [markdown]
# ### Question 24: Index and Value Tracking
#
# Given this code:
#
# ```
# set [data] to [create list with: 4, 7, 2, 9, 5, 3]
# set [maxVal] to [0]
# set [maxIdx] to [0]
# for [i] from [1] to [length of [data]] by [1]
#     if <item [i] of [data]> > [maxVal] then
#         set [maxVal] to [item [i] of [data]]
#         set [maxIdx] to [i]
# set [result] to [[maxVal] * [maxIdx]]
# ```
#
# What is the final value of `result`?
#
# A) 9
# B) 18
# C) 27
# D) 36
# E) 45

# %% [markdown]
# ### Question 25: Triangular Number
#
# Analyze this code:
#
# ```
# set [n] to [7]
# set [sum] to [0]
# for [i] from [1] to [n] by [1]
#     for [j] from [1] to [i] by [1]
#         change [sum] by [1]
# set [result] to [sum]
# ```
#
# What is the final value of `result`?
#
# A) 7
# B) 14
# C) 21
# D) 28
# E) 49

# %% [markdown]
# ### Question 26: Palindrome Check Pattern
#
# Examine this code:
#
# ```
# set [word] to ["LEVEL"]
# set [len] to [length of [word]]
# set [match] to [0]
# for [i] from [1] to [floor of [[len] / [2]]] by [1]
#     if <letter [i] in [word]> = <letter [[[len] - [i]] + [1] in [word]> then
#         change [match] by [1]
# set [result] to [match]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 1
# C) 2
# D) 3
# E) 5

# %% [markdown]
# ### Question 27: Conditional Accumulator
#
# Given this code:
#
# ```
# set [x] to [1]
# set [total] to [0]
# repeat [5] times
#     if <[x] mod [2]> = [1] then
#         change [total] by [x]
#         set [x] to [[x] * [2]]
#     else
#         change [total] by [[x] * [-1]]
#         set [x] to [[x] + [1]]
# set [result] to [total]
# ```
#
# What is the final value of `result`?
#
# A) 3
# B) 5
# C) 7
# D) 9
# E) 11

# %% [markdown]
# ### Question 28: Cumulative Product with Modulo
#
# Analyze this code:
#
# ```
# set [nums] to [create list with: 2, 3, 4]
# set [product] to [1]
# for each [n] in list [nums]
#     set [product] to [[product] * [n]]
# set [result] to [[product] mod [5]]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 1
# C) 2
# D) 3
# E) 4

# %% [markdown]
# ### Question 29: Complex Multi-Condition with Bonus
#
# Examine this code:
#
# ```
# set [scores] to [create list with: 85, 92, 78, 95, 88, 70, 100]
# set [bonus] to [0]
# set [count] to [0]
# for each [s] in list [scores]
#     if <[s] ≥ [90]> then
#         change [bonus] by [10]
#         change [count] by [1]
#     else
#         if <[s] ≥ [80]> then
#             change [bonus] by [5]
# set [result] to [[bonus] + [[count] * [count]]]
# ```
#
# What is the final value of `result`?
#
# A) 35
# B) 40
# C) 49
# D) 50
# E) 55

# %% [markdown]
# ### Question 30: Nested Loop Product Sum
#
# Given this code:
#
# ```
# set [sum] to [0]
# for [a] from [1] to [3] by [1]
#     for [b] from [1] to [a] by [1]
#         set [sum] to [[sum] + [[a] * [b]]]
# set [result] to [sum]
# ```
#
# What is the final value of `result`?
#
# A) 14
# B) 18
# C) 25
# D) 30
# E) 36
