# %% [markdown]
# # BLOCKLY PROGRAMMING - BỘ ĐỀ 03
# ## 20 Câu Hỏi Trắc Nghiệm Nâng Cao
# ### Dành cho học sinh lớp 6

# %% [markdown]
# ---
# ## PHẦN LÝ THUYẾT (30%)
# ---

# %% [markdown]
# ### Câu 1: Khối lặp
#
# Trong Blockly, khối "repeat 5 times" (lặp 5 lần) sẽ làm gì?
#
# A) Chạy các khối bên trong 4 lần
# B) Chạy các khối bên trong 5 lần
# C) Chạy các khối bên trong 6 lần
# D) Chạy các khối bên trong vô hạn lần
# E) Không chạy khối nào cả

# %% [markdown]
# ---
# ### Câu 2: Biến số
#
# Sau khi thực hiện các khối sau, giá trị của biến `x` là bao nhiêu?
#
# ```
# set [x] to [10]
# set [x] to [20]
# ```
#
# A) 10
# B) 20
# C) 30
# D) 0
# E) Lỗi

# %% [markdown]
# ---
# ### Câu 3: Khối điều kiện
#
# Khối "if-else" trong Blockly hoạt động như thế nào?
#
# A) Luôn chạy cả hai phần if và else
# B) Nếu điều kiện đúng thì chạy phần if, nếu sai thì chạy phần else
# C) Chỉ chạy phần else, bỏ qua phần if
# D) Chạy ngẫu nhiên một trong hai phần
# E) Không chạy phần nào cả

# %% [markdown]
# ---
# ### Câu 4: Phép chia lấy dư
#
# Trong Blockly, phép toán `7 mod 3` cho kết quả là bao nhiêu?
#
# A) 2
# B) 3
# C) 1
# D) 0
# E) 7

# %% [markdown]
# ---
# ### Câu 5: Danh sách (List)
#
# Trong Blockly, nếu danh sách `myList = [5, 10, 15, 20]`, thì `item 2 of myList` có giá trị là?
#
# A) 5
# B) 10
# C) 15
# D) 20
# E) 0

# %% [markdown]
# ---
# ### Câu 6: Thứ tự thực hiện
#
# Các khối trong Blockly được thực hiện theo thứ tự nào?
#
# A) Từ dưới lên trên
# B) Từ trên xuống dưới
# C) Ngẫu nhiên
# D) Cùng lúc tất cả
# E) Từ phải sang trái

# %% [markdown]
# ---
# ## PHẦN ỨNG DỤNG (70%)
# ---

# %% [markdown]
# ---
# ### Câu 7: Tính điểm
#
# Xem đoạn mã sau:
#
# ```
# set [điểm] to [0]
#
# repeat [4] times
#     change [điểm] by [5]
# ```
#
# Giá trị cuối cùng của `điểm` là bao nhiêu?
#
# A) 5
# B) 10
# C) 15
# D) 20
# E) 25

# %% [markdown]
# ---
# ### Câu 8: Đếm ngược
#
# Xem đoạn mã sau:
#
# ```
# set [số] to [50]
#
# repeat [3] times
#     change [số] by [-10]
#
# change [số] by [5]
# ```
#
# Giá trị cuối cùng của `số` là bao nhiêu?
#
# A) 15
# B) 20
# C) 25
# D) 30
# E) 35

# %% [markdown]
# ---
# ### Câu 9: Kiểm tra chẵn lẻ
#
# Xem đoạn mã sau:
#
# ```
# set [n] to [17]
# set [kết quả] to [""]
#
# if <[n] mod [2]> = [0] then
#     set [kết quả] to ["chẵn"]
# else
#     set [kết quả] to ["lẻ"]
# ```
#
# Giá trị của `kết quả` là gì?
#
# A) "chẵn"
# B) "lẻ"
# C) ""
# D) 17
# E) 0

# %% [markdown]
# ---
# ### Câu 10: Tính tổng danh sách
#
# Xem đoạn mã sau:
#
# ```
# set [danh sách] to [create list with: 2, 4, 6, 8]
# set [tổng] to [0]
#
# for each [số] in list [danh sách]
#     change [tổng] by [số]
# ```
#
# Giá trị cuối cùng của `tổng` là bao nhiêu?
#
# A) 8
# B) 10
# C) 16
# D) 20
# E) 24

# %% [markdown]
# ---
# ### Câu 11: Vòng lặp có điều kiện
#
# Xem đoạn mã sau:
#
# ```
# set [tiền] to [100]
# set [lần mua] to [0]
#
# repeat while <[tiền] ≥ [30]>
#     change [tiền] by [-30]
#     change [lần mua] by [1]
# ```
#
# Giá trị cuối cùng của `lần mua` là bao nhiêu?
#
# A) 2
# B) 3
# C) 4
# D) 5
# E) 10

# %% [markdown]
# ---
# ### Câu 12: Vòng lặp lồng nhau
#
# Xem đoạn mã sau:
#
# ```
# set [đếm] to [0]
#
# repeat [3] times
#     repeat [2] times
#         change [đếm] by [1]
# ```
#
# Giá trị cuối cùng của `đếm` là bao nhiêu?
#
# A) 2
# B) 3
# C) 5
# D) 6
# E) 9

# %% [markdown]
# ---
# ### Câu 13: Điều kiện trong vòng lặp
#
# Xem đoạn mã sau:
#
# ```
# set [danh sách] to [create list with: 1, 2, 3, 4, 5, 6]
# set [tổng chẵn] to [0]
#
# for each [n] in list [danh sách]
#     if <[n] mod [2]> = [0] then
#         change [tổng chẵn] by [n]
# ```
#
# Giá trị cuối cùng của `tổng chẵn` là bao nhiêu?
#
# A) 6
# B) 9
# C) 12
# D) 15
# E) 21

# %% [markdown]
# ---
# ### Câu 14: Xếp loại điểm
#
# Xem đoạn mã sau:
#
# ```
# set [điểm] to [75]
# set [xếp loại] to [""]
#
# if <[điểm] ≥ [90]> then
#     set [xếp loại] to ["Giỏi"]
# else if <[điểm] ≥ [70]> then
#     set [xếp loại] to ["Khá"]
# else if <[điểm] ≥ [50]> then
#     set [xếp loại] to ["Trung bình"]
# else
#     set [xếp loại] to ["Yếu"]
# ```
#
# Giá trị của `xếp loại` là gì?
#
# A) "Giỏi"
# B) "Khá"
# C) "Trung bình"
# D) "Yếu"
# E) ""

# %% [markdown]
# ---
# ### Câu 15: Nhân đôi liên tục
#
# Xem đoạn mã sau:
#
# ```
# set [số] to [3]
#
# repeat [4] times
#     set [số] to [[số] * [2]]
# ```
#
# Giá trị cuối cùng của `số` là bao nhiêu?
#
# A) 12
# B) 24
# C) 36
# D) 48
# E) 96

# %% [markdown]
# ---
# ### Câu 16: Đếm chữ cái
#
# Xem đoạn mã sau:
#
# ```
# set [từ] to ["HELLO"]
# set [đếm] to [0]
#
# for [i] from [1] to [length of [từ]] by [1]
#     if <letter [i] in [từ]> = ["L"] then
#         change [đếm] by [1]
# ```
#
# Giá trị cuối cùng của `đếm` là bao nhiêu?
#
# A) 1
# B) 2
# C) 3
# D) 4
# E) 5

# %% [markdown]
# ---
# ### Câu 17: Tính tiền mua sách
#
# Xem đoạn mã sau:
#
# ```
# set [giá sách] to [create list with: 25, 30, 15, 40]
# set [tổng tiền] to [0]
#
# for each [giá] in list [giá sách]
#     if <[giá] > [20]> then
#         change [tổng tiền] by [giá]
# ```
#
# Giá trị cuối cùng của `tổng tiền` là bao nhiêu?
#
# A) 55
# B) 70
# C) 95
# D) 110
# E) 40

# %% [markdown]
# ---
# ### Câu 18: Thao tác danh sách
#
# Xem đoạn mã sau:
#
# ```
# set [ds] to [create list with: 10, 20, 30]
# add [40] to list [ds]
# delete item [1] of [ds]
# set [kết quả] to [item [1] of [ds]]
# ```
#
# Giá trị của `kết quả` là bao nhiêu?
#
# A) 10
# B) 20
# C) 30
# D) 40
# E) 0

# %% [markdown]
# ---
# ### Câu 19: Tìm số lớn nhất
#
# Xem đoạn mã sau:
#
# ```
# set [các số] to [create list with: 15, 8, 23, 12, 19]
# set [max] to [item [1] of [các số]]
#
# for each [n] in list [các số]
#     if <[n] > [max]> then
#         set [max] to [n]
# ```
#
# Giá trị cuối cùng của `max` là bao nhiêu?
#
# A) 15
# B) 19
# C) 23
# D) 8
# E) 77

# %% [markdown]
# ---
# ### Câu 20: Bài toán tổng hợp
#
# Xem đoạn mã sau:
#
# ```
# set [a] to [1]
# set [b] to [1]
#
# repeat [4] times
#     set [c] to [[a] + [b]]
#     set [a] to [b]
#     set [b] to [c]
# ```
#
# Giá trị cuối cùng của `b` là bao nhiêu?
#
# A) 3
# B) 5
# C) 8
# D) 13
# E) 21
