# %% [markdown]
# # BLOCKLY PROGRAMMING - QUIZ 06
# ## 20 Intermediate Multiple Choice Questions
# ### Difficulty: Intermediate | Basic Concepts & Simple Code

# %% [markdown]
# ---
# ## THEORY QUESTIONS (30%)
# ---

# %% [markdown]
# ### Question 1: What is a Variable?
#
# In Blockly, what is a variable?
#
# A) A type of loop
# B) A named container that stores a value (number, text, list, etc.)
# C) A block that draws shapes
# D) A comparison operator
# E) A function that runs only once

# %% [markdown]
# ---
# ### Question 2: Repeat Block
#
# What does the block "repeat [5] times" do?
#
# A) Repeats forever
# B) Repeats 5 times
# C) Repeats until a condition is true
# D) Repeats only if a variable equals 5
# E) Does nothing

# %% [markdown]
# ---
# ### Question 3: Basic Arithmetic
#
# In Blockly, what is the result of the expression [8] + [5]?
#
# A) 85
# B) 13
# C) 3
# D) 40
# E) Error

# %% [markdown]
# ---
# ### Question 4: If-Then Block
#
# What does the "if &lt;condition&gt; then ... else ..." block do?
#
# A) Always runs the "then" part
# B) Runs the "then" part when the condition is true; otherwise runs the "else" part
# C) Runs both "then" and "else" every time
# D) Stops the program
# E) Repeats the condition 10 times

# %% [markdown]
# ---
# ### Question 5: What is a List?
#
# In Blockly, a list is:
#
# A) A single number
# B) A collection of items (numbers, text, etc.) in order
# C) A type of variable that cannot be changed
# D) A loop that runs backwards
# E) A comparison like &lt; or &gt;

# %% [markdown]
# ---
# ### Question 6: Set Variable Block
#
# What does "set [x] to [10]" do?
#
# A) Adds 10 to the current value of x
# B) Stores the value 10 in the variable x (replacing any previous value)
# C) Compares x with 10
# D) Deletes the variable x
# E) Prints 10 on the screen

# %% [markdown]
# ---
# ## APPLICATION QUESTIONS (70%)
# ---

# %% [markdown]
# ---
# ### Question 7: Simple Set and Change
#
# Analyze this Blockly code:
#
# ```
# set [a] to [5]
# change [a] by [3]
# set [result] to [a]
# ```
#
# What is the final value of `result`?
#
# A) 5
# B) 8
# C) 3
# D) 15
# E) 2

# %% [markdown]
# ---
# ### Question 8: Simple Loop - Add Repeatedly
#
# Examine this Blockly code:
#
# ```
# set [sum] to [0]
# repeat [4] times
#     change [sum] by [2]
# set [result] to [sum]
# ```
#
# What is the final value of `result`?
#
# A) 2
# B) 4
# C) 6
# D) 8
# E) 0

# %% [markdown]
# ---
# ### Question 9: Simple If-Else
#
# Given this Blockly code:
#
# ```
# set [x] to [7]
# if <[x] > [5]> then
#     set [y] to [10]
# else
#     set [y] to [0]
# set [result] to [y]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 5
# C) 7
# D) 10
# E) 12

# %% [markdown]
# ---
# ### Question 10: Get Item from List
#
# In Blockly, if `myList = [10, 20, 30, 40]`, what does "item [2] of [myList]" return?
#
# A) 10
# B) 20
# C) 30
# D) 40
# E) 2

# %% [markdown]
# ---
# ### Question 11: Join Strings
#
# In Blockly, what is the result of join ["Hello"] ["!"]?
#
# A) "Hello "
# B) "!Hello"
# C) "Hello!"
# D) "Hello" "!"
# E) Error

# %% [markdown]
# ---
# ### Question 12: Simple For Loop Sum
#
# Analyze this Blockly code:
#
# ```
# set [total] to [0]
# for [i] from [1] to [3] by [1]
#     set [total] to [[total] + [i]]
# set [result] to [total]
# ```
#
# What is the final value of `result`?
#
# A) 1
# B) 3
# C) 6
# D) 0
# E) 4

# %% [markdown]
# ---
# ### Question 13: Length of String
#
# In Blockly, what is "length of [\"ABC\"]"?
#
# A) "A"
# B) 1
# C) 2
# D) 3
# E) "ABC"

# %% [markdown]
# ---
# ### Question 14: Simple Comparison
#
# Examine this Blockly code:
#
# ```
# set [n] to [15]
# if <[n] ≥ [10]> then
#     set [result] to [1]
# else
#     set [result] to [0]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 1
# C) 10
# D) 15
# E) 5

# %% [markdown]
# ---
# ### Question 15: Modulo Operator
#
# In Blockly, what is the result of [10] mod [3]?
#
# A) 3
# B) 1
# C) 0
# D) 10
# E) 3.33

# %% [markdown]
# ---
# ### Question 16: Letter in String
#
# In Blockly, if `text = "CAT"`, what does "letter [2] in [text]" return?
#
# A) "C"
# B) "A"
# C) "T"
# D) 2
# E) "CA"

# %% [markdown]
# ---
# ### Question 17: Loop Through List - Count
#
# Given this Blockly code:
#
# ```
# set [nums] to [create list with: 5, 10, 15, 20]
# set [count] to [0]
# for each [n] in list [nums]
#     change [count] by [1]
# set [result] to [count]
# ```
#
# What is the final value of `result`?
#
# A) 4
# B) 5
# C) 50
# D) 20
# E) 0

# %% [markdown]
# ---
# ### Question 18: Simple Arithmetic Expression
#
# Analyze this Blockly code:
#
# ```
# set [a] to [6]
# set [b] to [4]
# set [result] to [[[a] * [2]] + [b]]
# ```
#
# What is the final value of `result`?
#
# A) 10
# B) 12
# C) 16
# D) 20
# E) 24

# %% [markdown]
# ---
# ### Question 19: Sum of Small List
#
# Examine this Blockly code:
#
# ```
# set [data] to [create list with: 3, 7, 2]
# set [sum] to [0]
# for each [n] in list [data]
#     set [sum] to [[sum] + [n]]
# set [result] to [sum]
# ```
#
# What is the final value of `result`?
#
# A) 3
# B) 7
# C) 12
# D) 2
# E) 0

# %% [markdown]
# ---
# ### Question 20: Find Maximum of Three
#
# Given this Blockly code:
#
# ```
# set [a] to [12]
# set [b] to [18]
# set [c] to [15]
# set [max] to [a]
# if <[b] > [max]> then
#     set [max] to [b]
# if <[c] > [max]> then
#     set [max] to [c]
# set [result] to [max]
# ```
#
# What is the final value of `result`?
#
# A) 12
# B) 15
# C) 18
# D) 45
# E) 0
