# %% [markdown]
# # BLOCKLY PROGRAMMING - QUIZ 05
# ## 20 Expert-Level Multiple Choice Questions
# ### Difficulty: Expert | Advanced Algorithm Application

# %% [markdown]
# ---
# ## THEORY QUESTIONS (30%)
# ---

# %% [markdown]
# ### Question 1: Function Return Values
#
# In Blockly, what happens if a function with a return value is called but the return value is not used?
#
# A) The program crashes with an error
# B) The return value is discarded and execution continues normally
# C) The return value is automatically stored in a variable called "result"
# D) The function does not execute
# E) An infinite loop occurs

# %% [markdown]
# ---
# ### Question 2: Nested Boolean Logic
#
# Given `a = true`, `b = false`, `c = true`, what is the result of:
#
# `<<not <a>> or <b>> and <<c> or <not <b>>>`
#
# A) true
# B) false
# C) Error
# D) undefined
# E) null

# %% [markdown]
# ---
# ### Question 3: List Mutation During Iteration
#
# What potential issue can occur when deleting items from a list while iterating through it with `for each [item] in list [myList]`?
#
# A) No issues, Blockly handles this automatically
# B) Some items may be skipped because indices shift after deletion
# C) The program will crash immediately
# D) All items will be deleted automatically
# E) The list becomes read-only during iteration

# %% [markdown]
# ---
# ### Question 4: Order of Operations
#
# In Blockly, what is the result of this expression:
#
# `[[10] - [3]] * [[2] + [1]]`
#
# A) 5
# B) 11
# C) 21
# D) 9
# E) 30

# %% [markdown]
# ---
# ### Question 5: Break vs Continue
#
# In Blockly loops, what is the difference between `break out of loop` and `continue with next iteration`?
#
# A) They are the same thing
# B) `break` exits the loop entirely; `continue` skips to the next iteration
# C) `break` skips one iteration; `continue` exits the loop
# D) `break` only works in while loops; `continue` only works in for loops
# E) Neither exists in Blockly

# %% [markdown]
# ---
# ### Question 6: Floating Point Division
#
# In Blockly, what is the result of `[7] / [2]`?
#
# A) 3
# B) 3.5
# C) 4
# D) 3.0
# E) Error: cannot divide odd by even

# %% [markdown]
# ---
# ## APPLICATION QUESTIONS (70%)
# ---

# %% [markdown]
# ---
# ### Question 7: Prime Number Detection
#
# Analyze the following Blockly code:
#
# ```
# set [n] to [29]
# set [isPrime] to [true]
# set [i] to [2]
#
# repeat while <<[i] * [i]> ≤ [n]>
#     if <[n] mod [i]> = [0] then
#         set [isPrime] to [false]
#     change [i] by [1]
#
# if <[isPrime]> = [true] then
#     set [result] to [[n] * [2]]
# else
#     set [result] to [0]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 29
# C) 58
# D) 1
# E) 87

# %% [markdown]
# ---
# ### Question 8: Nested Loop with Early Exit
#
# Examine this Blockly code:
#
# ```
# set [found] to [0]
#
# for [i] from [1] to [5] by [1]
#     for [j] from [1] to [5] by [1]
#         if <[i] * [j]> = [12] then
#             set [found] to [[i] + [j]]
#             break out of loop
# ```
#
# What is the final value of `found`?
#
# A) 0
# B) 7
# C) 8
# D) 12
# E) 5

# %% [markdown]
# ---
# ### Question 9: Function with Multiple Calls
#
# Given this Blockly code:
#
# ```
# define function [double] with parameter [x]
#     return [[x] * [2]]
#
# define function [addFive] with parameter [x]
#     return [[x] + [5]]
#
# set [a] to [call [double] with [3]]
# set [b] to [call [addFive] with [a]]
# set [c] to [call [double] with [b]]
# set [result] to [[c] - [a]]
# ```
#
# What is the final value of `result`?
#
# A) 11
# B) 16
# C) 22
# D) 28
# E) 6

# %% [markdown]
# ---
# ### Question 10: Reverse String Algorithm
#
# Analyze this Blockly code:
#
# ```
# set [text] to ["ROBOT"]
# set [reversed] to [""]
# set [len] to [length of [text]]
#
# for [i] from [len] to [1] by [-1]
#     set [reversed] to [join [reversed] [letter [i] in [text]]]
#
# set [result] to [letter [3] in [reversed]]
# ```
#
# What is the value of `result`?
#
# A) "R"
# B) "O"
# C) "B"
# D) "T"
# E) "Error"

# %% [markdown]
# ---
# ### Question 11: Two-Pointer Pattern
#
# Examine this Blockly code:
#
# ```
# set [arr] to [create list with: 1, 3, 5, 7, 9, 11]
# set [left] to [1]
# set [right] to [length of [arr]]
# set [sum] to [0]
#
# repeat while <[left] < [right]>
#     set [sum] to [[sum] + [item [left] of [arr]] + [item [right] of [arr]]]
#     change [left] by [1]
#     change [right] by [-1]
# ```
#
# What is the final value of `sum`?
#
# A) 12
# B) 24
# C) 36
# D) 48
# E) 30

# %% [markdown]
# ---
# ### Question 12: Count Occurrences in Nested List
#
# Given this Blockly code:
#
# ```
# set [matrix] to [create list with: [create list with: 1, 2, 3], [create list with: 2, 3, 4], [create list with: 3, 4, 5]]
# set [target] to [3]
# set [count] to [0]
#
# for each [row] in list [matrix]
#     for each [cell] in list [row]
#         if <[cell]> = [target] then
#             change [count] by [1]
# ```
#
# What is the final value of `count`?
#
# A) 1
# B) 2
# C) 3
# D) 4
# E) 9

# %% [markdown]
# ---
# ### Question 13: Geometric Series Sum
#
# Analyze this Blockly code:
#
# ```
# set [sum] to [0]
# set [term] to [1]
#
# repeat [6] times
#     set [sum] to [[sum] + [term]]
#     set [term] to [[term] * [2]]
# ```
#
# What is the final value of `sum`?
#
# A) 32
# B) 63
# C) 64
# D) 127
# E) 31

# %% [markdown]
# ---
# ### Question 14: Bubble Sort Step Counter
#
# Examine this Blockly code:
#
# ```
# set [arr] to [create list with: 5, 3, 8, 1, 9]
# set [swaps] to [0]
# set [n] to [length of [arr]]
#
# for [i] from [1] to [[n] - [1]] by [1]
#     for [j] from [1] to [[n] - [i]] by [1]
#         if <item [j] of [arr]> > <item [[j] + [1]] of [arr]> then
#             set [temp] to [item [j] of [arr]]
#             replace item [j] of [arr] with [item [[j] + [1]] of [arr]]
#             replace item [[j] + [1]] of [arr] with [temp]
#             change [swaps] by [1]
# ```
#
# What is the final value of `swaps`?
#
# A) 3
# B) 4
# C) 5
# D) 6
# E) 10

# %% [markdown]
# ---
# ### Question 15: Power Function with Loop
#
# Given this Blockly code:
#
# ```
# set [base] to [3]
# set [exp] to [4]
# set [result] to [1]
#
# repeat [exp] times
#     set [result] to [[result] * [base]]
#
# set [final] to [[result] mod [10]]
# ```
#
# What is the final value of `final`?
#
# A) 1
# B) 3
# C) 9
# D) 27
# E) 81

# %% [markdown]
# ---
# ### Question 16: Multiple Condition Filtering
#
# Analyze this Blockly code:
#
# ```
# set [nums] to [create list with: 12, 15, 20, 25, 30, 35, 40]
# set [count] to [0]
# set [sum] to [0]
#
# for each [n] in list [nums]
#     if <<[n] mod [5]> = [0]> and <<[n] mod [3]> ≠ [0]> then
#         change [count] by [1]
#         change [sum] by [n]
#
# set [result] to [[sum] / [count]]
# ```
#
# What is the final value of `result`?
#
# A) 25
# B) 30
# C) 35
# D) 40
# E) 20

# %% [markdown]
# ---
# ### Question 17: Character Frequency Counter
#
# Examine this Blockly code:
#
# ```
# set [text] to ["MISSISSIPPI"]
# set [target] to ["S"]
# set [count] to [0]
# set [positions] to [create empty list]
#
# for [i] from [1] to [length of [text]] by [1]
#     if <letter [i] in [text]> = [target] then
#         change [count] by [1]
#         add [i] to list [positions]
#
# set [result] to [[count] * [item [1] of [positions]]]
# ```
#
# What is the final value of `result`?
#
# A) 3
# B) 8
# C) 12
# D) 16
# E) 4

# %% [markdown]
# ---
# ### Question 18: Recursive-like Factorial
#
# Given this Blockly code:
#
# ```
# set [n] to [5]
# set [factorial] to [1]
# set [i] to [n]
#
# repeat while <[i] > [1]>
#     set [factorial] to [[factorial] * [i]]
#     change [i] by [-1]
#
# set [result] to [[factorial] mod [13]]
# ```
#
# What is the final value of `result`?
#
# A) 0
# B) 3
# C) 6
# D) 10
# E) 120

# %% [markdown]
# ---
# ### Question 19: Min-Max Difference
#
# Analyze this Blockly code:
#
# ```
# set [data] to [create list with: 45, 23, 67, 12, 89, 34]
# set [min] to [item [1] of [data]]
# set [max] to [item [1] of [data]]
#
# for each [n] in list [data]
#     if <[n] < [min]> then
#         set [min] to [n]
#     if <[n] > [max]> then
#         set [max] to [n]
#
# set [result] to [[max] - [min]]
# ```
#
# What is the final value of `result`?
#
# A) 66
# B) 77
# C) 55
# D) 89
# E) 12

# %% [markdown]
# ---
# ### Question 20: Complex Multi-Step Algorithm
#
# Examine this comprehensive Blockly code:
#
# ```
# set [nums] to [create list with: 8, 15, 3, 22, 7, 18, 11]
# set [evenSum] to [0]
# set [oddCount] to [0]
# set [threshold] to [10]
#
# for each [n] in list [nums]
#     if <[n] mod [2]> = [0] then
#         change [evenSum] by [n]
#     else
#         if <[n] > [threshold]> then
#             change [oddCount] by [1]
#
# set [result] to [[[evenSum] / [2]] + [[oddCount] * [oddCount] * [oddCount]]]
# ```
#
# What is the final value of `result`?
#
# A) 24
# B) 32
# C) 35
# D) 48
# E) 51
